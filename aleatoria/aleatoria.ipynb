# %%
import numpy as np
import pandas as pd
import sympy as sp
from numpy.random import random as rnd

# %%
rnd()
# Out:
# 0.1298479447174543

# %%
x, y = sp.symbols('x y')

# %%
f_str = sp.sympify()
